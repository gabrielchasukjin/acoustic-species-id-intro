# %% [markdown]
# ### Stratified Random Sampling System

# %% [markdown]
# ### Strata Layers
# 1. Audiomoth device (given it contains enough clips)
# 2. Time of day (0-23)
#
# ### Two Strata Layers
# 1. Audiomoth device (given it contains enough clips)
# 2. Time of day (0-23)
#
# ---
#
# #### Reasoning behind Strata Layer 1
#
# As the repo states, looks like `[AM-21, AM-19, AM-28]`are not found in the CSV.
# - However, the GitHub repo notes that `AM-8`has problems but just by looking at the CSV alone, it looks functional (i.e. contains meaningful data). AM-8 is inlcuded in the strata layer.
#
# `[AM-12,AM-13,AM-18]` were not included as groups in the first strata layer becuase they contained less than a couple hundred clips collectively. Only those with more than 2000 clips were added to the first layer.
#
# **First Layer:** `['AM-1', 'AM-10', 'AM-11', 'AM-14', 'AM-15', 'AM-16', 'AM-17','AM-2', 'AM-20', 'AM-22', 'AM-23', 'AM-24', 'AM-25', 'AM-26','AM-27', 'AM-29', 'AM-3', 'AM-30', 'AM-4', 'AM-5', 'AM-6', 'AM-7','AM-8', 'AM-9', 'WWF-1', 'WWF-2', 'WWF-3', 'WWF-4', 'WWF-5']`
#
# **Total of 29 Groups**
#
# ---
#
# #### Reasoning behind Strata Layer 2
#
# I noticed the `Comments` column contains the time of day that the audio was recorded. I used .split() method to extract the hour mark, resulting in 24 groups.
#
# ---
#
# #### Stratified groups
#
# 29 successful audiomoths * 24 hours = 696 combos
#
# In total the stratified sampling should return **696 groups**.

# %%
import pandas as pd
import numpy as np

# %%
dashboard_df = pd.read_csv('Peru_2019_AudioMoth_Data_Full.csv', sep=',', index_col=False, dtype='unicode')

# %%
dashboard_df.head(3)
# Out:
#   AudioMothCode       AudioMothID                              SourceFile  \
# 0          AM-1  243B1F055B2BEAB8  GRABADOR-SDZG-AM-1/20190616_145649.WAV
# 1          AM-1  243B1F055B2BEAB8  GRABADOR-SDZG-AM-1/20190616_150000.WAV
# 2          AM-1  243B1F055B2BEAB8  GRABADOR-SDZG-AM-1/20190616_151000.WAV
#
#             Directory             FileName  FileSize Encoding NumChannels  \
# 0  GRABADOR-SDZG-AM-1  20190616_145649.WAV   1802240        1           1
# 1  GRABADOR-SDZG-AM-1  20190616_150000.WAV  46080360        1           1
# 2  GRABADOR-SDZG-AM-1  20190616_151000.WAV  46080360        1           1
#
#   SampleRate AvgBytesPerSec BitsPerSample     StartDateTime     Duration  \
# 0     384000         768000            16  16.06.2019 14:56  2.346666667
# 1     384000         768000            16  16.06.2019 15:00  60.00046875
# 2     384000         768000            16  16.06.2019 15:10  60.00046875
#
#   Error                                            Comment  \
# ...

# %% [markdown]
# ### Data Cleaning
# Ensure clips are a minute long.

# %%
dashboard_df['Duration'] = pd.to_numeric(dashboard_df['Duration'], errors='coerce')
dashboard_df = dashboard_df[dashboard_df["Duration"] > 60]
dashboard_df
# Out:
#       AudioMothCode       AudioMothID                              SourceFile  \
# 1              AM-1  243B1F055B2BEAB8  GRABADOR-SDZG-AM-1/20190616_150000.WAV
# 2              AM-1  243B1F055B2BEAB8  GRABADOR-SDZG-AM-1/20190616_151000.WAV
# 3              AM-1  243B1F055B2BEAB8  GRABADOR-SDZG-AM-1/20190616_152000.WAV
# 4              AM-1  243B1F055B2BEAB8  GRABADOR-SDZG-AM-1/20190616_153000.WAV
# 5              AM-1  243B1F055B2BEAB8  GRABADOR-SDZG-AM-1/20190616_154000.WAV
# ...             ...               ...                                     ...
# 98489         WWF-5               NaN             GRABADOR-WWF-5/5D2FC490.WAV
# 98492         WWF-5               NaN             GRABADOR-WWF-5/5D2FCB98.WAV
# 98493         WWF-5               NaN             GRABADOR-WWF-5/5D2FCDF0.WAV
# 98497         WWF-5               NaN             GRABADOR-WWF-5/5D2FD750.WAV
# 98511         WWF-5               NaN             GRABADOR-WWF-5/5D2FF820.WAV
#
# ...

# %% [markdown]
# ### Strata 1: Audiomoth Devices

# %%
dashboard_df.groupby("AudioMothCode").count()
# Out:
#                AudioMothID  SourceFile  Directory  FileName  FileSize  \
# AudioMothCode
# AM-1                  2740        2740       2740      2740      2740
# AM-10                 2680        2680       2680      2680      2680
# AM-11                 2730        2730       2730      2730      2730
# AM-12                  671         671        671       671       671
# AM-13                  218         218        218       218       218
# AM-14                 3485        3485       3485      3485      3485
# AM-15                 2723        2723       2723      2723      2723
# AM-16                 2694        2694       2694      2694      2694
# AM-17                 2776        2776       2776      2776      2776
# AM-18                    8           8          8         8         8
# AM-2                  2760        2760       2760      2760      2760
# AM-20                 2571        2571       2571      2571      2571
# ...

# %% [markdown]
# ### Filtering
# As the repo states, looks like `[AM-21, AM-19, AM-28]`are not found in the CSV.
# - The GitHub repo notes that `AM-8`has problems but just by looking at the CSV, it looks functional.
#
# For the strata I'll only include Audiomoths with greater than 2000 clips.

# %%
df_group = dashboard_df.groupby("AudioMothCode").filter(lambda df: df['FileName'].count() > 2000)
df_groups = df_group.groupby("AudioMothCode").count()
df_groups
# Out:
#                AudioMothID  SourceFile  Directory  FileName  FileSize  \
# AudioMothCode
# AM-1                  2740        2740       2740      2740      2740
# AM-10                 2680        2680       2680      2680      2680
# AM-11                 2730        2730       2730      2730      2730
# AM-14                 3485        3485       3485      3485      3485
# AM-15                 2723        2723       2723      2723      2723
# AM-16                 2694        2694       2694      2694      2694
# AM-17                 2776        2776       2776      2776      2776
# AM-2                  2760        2760       2760      2760      2760
# AM-20                 2571        2571       2571      2571      2571
# AM-22                 3169        3169       3169      3169      3169
# AM-23                 3623        3623       3623      3623      3623
# AM-24                 3766        3766       3766      3766      3766
# ...

# %% [markdown]
# ### Strata Audiomoth Device Groups

# %%
# Strata Audiomoth Device Groups 
df_groups.index.values.tolist()
# Out:
# ['AM-1',
#  'AM-10',
#  'AM-11',
#  'AM-14',
#  'AM-15',
#  'AM-16',
#  'AM-17',
#  'AM-2',
#  'AM-20',
#  'AM-22',
#  'AM-23',
#  'AM-24',
#  'AM-25',
#  'AM-26',
#  'AM-27',
#  'AM-29',
#  'AM-3',
#  'AM-30',
#  'AM-4',
#  'AM-5',
#  'AM-6',
#  'AM-7',
#  'AM-8',
#  'AM-9',
#  'WWF-1',
#  'WWF-2',
#  'WWF-3',
#  'WWF-4',
#  'WWF-5']

# %%
len(df_groups.index.values.tolist())
# Out:
# 29

# %% [markdown]
# **Summary** : 29 Groups in Strata 1 (Audiomoth Devices)

# %% [markdown]
# ## Strata 2: Time of Day
# Convert timestamp into hour marks.

# %%
# Ensure that none of the Timestamps are missing 
df_group['Comment'].isna().sum()
# Out:
# 0

# %%
dashboard_df['Comment'].iloc[0]
# Out:
# 'Recorded at 15:00:00 16/06/2019 (UTC) by AudioMoth 243B1F055B2BEAB8 at gain setting 2 while battery state was 4.7V.'

# %% [markdown]
# Extract the timestamp by using .split()

# %%
def extract_hour(time):
    return int(time.split('at ')[1].split(':')[0])

# %%
extract_hour(dashboard_df['Comment'].iloc[0])
# Out:
# 15

# %%
dashboard_df_hour= df_group.assign(Hour = df_group['Comment'].apply(extract_hour))
dashboard_df_hour
# Out:
#       AudioMothCode       AudioMothID                              SourceFile  \
# 1              AM-1  243B1F055B2BEAB8  GRABADOR-SDZG-AM-1/20190616_150000.WAV
# 2              AM-1  243B1F055B2BEAB8  GRABADOR-SDZG-AM-1/20190616_151000.WAV
# 3              AM-1  243B1F055B2BEAB8  GRABADOR-SDZG-AM-1/20190616_152000.WAV
# 4              AM-1  243B1F055B2BEAB8  GRABADOR-SDZG-AM-1/20190616_153000.WAV
# 5              AM-1  243B1F055B2BEAB8  GRABADOR-SDZG-AM-1/20190616_154000.WAV
# ...             ...               ...                                     ...
# 98489         WWF-5               NaN             GRABADOR-WWF-5/5D2FC490.WAV
# 98492         WWF-5               NaN             GRABADOR-WWF-5/5D2FCB98.WAV
# 98493         WWF-5               NaN             GRABADOR-WWF-5/5D2FCDF0.WAV
# 98497         WWF-5               NaN             GRABADOR-WWF-5/5D2FD750.WAV
# 98511         WWF-5               NaN             GRABADOR-WWF-5/5D2FF820.WAV
#
# ...

# %% [markdown]
# **Summary**: Created a new column with the clip's hourly mark

# %% [markdown]
# ## Randomly Sample from Each Strata Combination

# %% [markdown]
# 29 working audiomoths * 24 hours equals **696** stratified samples

# %%
len(df_groups.index.values) * 24
# Out:
# 696

# %%
# Randomly choosing one sample from each strata group
dashboard_df_hour.groupby(['AudioMothCode','Hour']).sample(n=1)
# Out:
#       AudioMothCode       AudioMothID                              SourceFile  \
# 1787           AM-1  243B1F055B2BEAB8  GRABADOR-SDZG-AM-1/20190629_004000.WAV
# 2223           AM-1  243B1F055B2BEAB8  GRABADOR-SDZG-AM-1/20190702_012000.WAV
# 213            AM-1  243B1F055B2BEAB8  GRABADOR-SDZG-AM-1/20190618_022000.WAV
# 941            AM-1  243B1F055B2BEAB8  GRABADOR-SDZG-AM-1/20190623_034000.WAV
# 225            AM-1  243B1F055B2BEAB8  GRABADOR-SDZG-AM-1/20190618_042000.WAV
# ...             ...               ...                                     ...
# 98168         WWF-5               NaN             GRABADOR-WWF-5/5D2CD438.WAV
# 98171         WWF-5               NaN             GRABADOR-WWF-5/5D2CDB40.WAV
# 97174         WWF-5               NaN             GRABADOR-WWF-5/5D23BA88.WAV
# 95591         WWF-5               NaN             GRABADOR-WWF-5/5D153C60.WAV
# 96321         WWF-5               NaN             GRABADOR-WWF-5/5D1BEB50.WAV
#
# ...

# %% [markdown]
# ### Stratified Random Sample Function

# %%
path_csv = 'Peru_2019_AudioMoth_Data_Full.csv'

# %%
def stratified_random_sample(path):
    
    # read csv
    dashboard_df = pd.read_csv(path, sep=',', index_col=False, dtype='unicode')
    
    # filter for minute long clips 
    dashboard_df['Duration'] = pd.to_numeric(dashboard_df['Duration'], errors='coerce')
    dashboard_df = dashboard_df[dashboard_df["Duration"] > 60]
    
    # filter for audiomoths containg enough clips (i.e. > 2000) (29 Successful Audiomoths)
    df_group = dashboard_df.groupby("AudioMothCode").filter(lambda df: df['FileName'].count() > 2000)
    
    # extract hour mark from Comment column 
    def extract_hour(time):
        return int(time.split('at ')[1].split(':')[0])
    
    # apply extract_hour (24 hour clips)
    dashboard_df_hour= df_group.assign(Hour = df_group['Comment'].apply(extract_hour))
    
    # sample one clip from each strata group (ex. strata audiomoth AM-1 in Hour 0)
    df_csv = dashboard_df_hour.groupby(['AudioMothCode','Hour']).sample(n=1)
    
    df_csv.to_csv('stratified_random_sample.csv', sep=',')
    
    # check if csv has (29 Successful Audiomoths) * (24 clips)
    if (df_csv.shape[0] == len(df_groups.index.values) * 24):
        return True 
    
    else:
        return False

# %% [markdown]
# ### Function Output

# %%
stratified_random_sample('Peru_2019_AudioMoth_Data_Full.csv')
# Out:
# True

# %% [markdown]
# ### Read newly created csv

# %%
pd.read_csv('stratified_random_sample.csv', sep=',', index_col=False, dtype='unicode')
# Out:
#     Unnamed: 0 AudioMothCode       AudioMothID  \
# 0         1210          AM-1  243B1F055B2BEAB8
# 1         1792          AM-1  243B1F055B2BEAB8
# 2         1223          AM-1  243B1F055B2BEAB8
# 3         1373          AM-1  243B1F055B2BEAB8
# 4          657          AM-1  243B1F055B2BEAB8
# ..         ...           ...               ...
# 691      97017         WWF-5               NaN
# 692      96591         WWF-5               NaN
# 693      97169         WWF-5               NaN
# 694      96748         WWF-5               NaN
# 695      97039         WWF-5               NaN
#
#                                  SourceFile           Directory  \
# 0    GRABADOR-SDZG-AM-1/20190625_003000.WAV  GRABADOR-SDZG-AM-1
# 1    GRABADOR-SDZG-AM-1/20190629_013000.WAV  GRABADOR-SDZG-AM-1
# 2    GRABADOR-SDZG-AM-1/20190625_024000.WAV  GRABADOR-SDZG-AM-1
# 3    GRABADOR-SDZG-AM-1/20190626_034000.WAV  GRABADOR-SDZG-AM-1
# 4    GRABADOR-SDZG-AM-1/20190621_042000.WAV  GRABADOR-SDZG-AM-1
# ...

# %% [markdown]
# ## Summary
#
# ### Two Strata Layers
# 1. Audiomoth device (given it contains enough clips)
# 2. Time of day (0-23)
#
# ---
#
# #### Reasoning behind Strata Layer 1
#
# As the repo states, looks like `[AM-21, AM-19, AM-28]`are not found in the CSV.
# - However, the GitHub repo notes that `AM-8`has problems but just by looking at the CSV alone, it looks functional (i.e. contains meaningful data). AM-8 is inlcuded in the strata layer.
#
# `[AM-12,AM-13,AM-18]` were not included as groups in the first strata layer becuase they contained less than a couple hundred clips collectively. Only those with more than 2000 clips were added to the first layer.
#
# **First Layer:** `['AM-1', 'AM-10', 'AM-11', 'AM-14', 'AM-15', 'AM-16', 'AM-17','AM-2', 'AM-20', 'AM-22', 'AM-23', 'AM-24', 'AM-25', 'AM-26','AM-27', 'AM-29', 'AM-3', 'AM-30', 'AM-4', 'AM-5', 'AM-6', 'AM-7','AM-8', 'AM-9', 'WWF-1', 'WWF-2', 'WWF-3', 'WWF-4', 'WWF-5']`
#
# **Total of 29 Groups**
#
# ---
#
# #### Reasoning behind Strata Layer 2
#
# I noticed the `Comments` column contains the time of day that the audio was recorded. I used .split() method to extract the hour mark, resulting in 24 groups.
#
# ---
#
# #### Stratified groups
#
# 29 successful audiomoths * 24 hours = 696 combos
#
# In total the stratified sampling should return **696 groups**.
